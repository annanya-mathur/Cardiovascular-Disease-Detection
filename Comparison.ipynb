# %% [markdown]
# <a href="https://colab.research.google.com/github/annanya-mathur/Cardiovascular-Disease-Detection/blob/main/Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as pt
from mpl_toolkits.mplot3d import axes3d

# %%
dataframe= pd.read_csv('/content/cardio-statlog_csv.csv')

# %%
dataframe.head(5)
# Out:
#    age  sex  chest  ...  thal  cardio  diabetes
# 0   70    1      4  ...     3       1         1
# 1   67    0      3  ...     7       0         0
# 2   57    1      2  ...     7       1         1
# 3   64    1      4  ...     7       0         1
# 4   74    0      2  ...     3       0         0
#
# [5 rows x 15 columns]

# %% [markdown]
# **Relation** **between** **Diabetes** **and** **cardio**
#
# > The graph shows linear relationship i.e. increasing case of diabetes leads to more cardiovascular problems

# %%
f=pt.figure()  # 3-D plot of polygons
a=f.add_subplot(111,projection='3d')
max=dataframe['diabetes']
cardio=dataframe['cardio']
a.plot(max,cardio)
pt.grid(True ,color='k')

# %% [markdown]
# **Realation between age and cardio**

# %%
sb.relplot("age","cardio",data=dataframe,estimator=sum,kind="line" )
pt.grid(True ,color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Relationship** **between** **cardio** **and** **major** **vessels** **in** **heart**

# %%
sb.relplot("number_of_major_vessels","cardio",data=dataframe,kind="line" ,color='g')
pt.grid(True ,color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Relationship** **between** **bp** **and** **cardio**

# %%
sb.relplot("resting_blood_pressure","cardio",data=dataframe,kind="line",color='g',estimator=sum)
pt.grid(True ,color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **People** **having** **diabetes** **and** **higher** **age** **contributes** **to** **cardio** **sometimes** **but** **not** **in** **every** **case**
#
# > For eg, at age 70 both the cases of having and not having such disease can be found . This can be achieved by changing lifestyle by taking heathly diet and living with nature.
#
# >![health-png-6 (1) (1).jpg](data:image/jpeg;base64,...)

# %%
sb.relplot("age","cardio",hue="diabetes",data=dataframe,kind="line" )
pt.grid(True ,color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.relplot("cardio","serum_cholestoral",hue="chest",data=dataframe,kind="line",style="diabetes")
sb.color_palette("Spectral",as_cmap=True)
pt.grid(True ,color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
